# %% [markdown]
# <font color ='green'>Cassandra Gray and Saajan Gandhi</font>

# %% [markdown]
# **Group 2: Climate Soldiers**

# %% [markdown]
# ![dj's](https://media.giphy.com/media/1N2pvjrlYSVR2WOqiI/giphy.gif)

# %% [markdown]
# # INTRODUCTION:

# %% [markdown]
# We decided to pick topics that relate to what could go into making a neighborhood more <font color ='green'>eco friendly</font>. We’ll be seeing which neighborhood significantly reduces waste generation and promotes the reuse and recycling of waste products, because this will essentially prevent the buildup of waste and make the neighborhood better to live in. Other datasets that came to mind when trying to calculate the "ecofriendlyness" of a neighborhood was the Watershed and Tree locations and quantities in each neighborhood. After finding the ones we did ( <font color ='green'>Smart Trash Containers, Greenways, and Food Gardens</font>) we decided they'd be better choices.

# %% [markdown]
# # METRIC:
#
# To calculate which neighborhood is the best we’ll see which one of them has the largest amount of
# - Smart Trash Containers
# - Greenways
# - Food Gardens

# %% [markdown]
# # Code:

# %% [markdown]
# Firstly, we'd import the pandas and the pyplot for matplotlib. Then we'll read in <font color ='green'>Dataset 1: Smart Trash Containers</font> which displays the quantitiy of containers in each neighborhood.

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ## DATASET 1: Smart Trash Containers 🗑

# %% [markdown]
# ![smarttrash.png](attachment:f6a2fff1-e43e-464a-ae37-cdfd19ef6a47.png)

# %%
smartTrashContainers = pd.read_csv('https://data.wprdc.org/datastore/dump/75b83ac9-8069-4cf1-bcc3-b9e6b04487d9')
zip_code = {}
for index, row in smartTrashContainers.iterrows():
    item = row['zip']
    if item in zip_code:
        zip_code[item] += 1
        continue
    else:
        zip_code[item] = 1
        
for key in zip_code:
    print(key)
    print(zip_code[key])
    print("--------")
# Out:
# 15212
# 166
# --------
# 15233
# 26
# --------
# 15214
# 29
# --------
# 15219
# 111
# --------
# 15224
# 62
# --------
# 15210
# 60
# --------
# 15207
# 30
# --------
# 15206
# 149
# --------
# 15227
# 6
# --------
# 15217
# 99
# --------
# 15216
# 10
# --------
# 15208
# 38
# --------
# 15226
# 17
# --------
# 15213
# 67
# --------
# 15232
# 59
# --------
# 15203
# 55
# --------
# 15220
# 23
# --------
# 15211
# 27
# --------
# 15204
# 20
# --------
# 15205
# 10
# --------
# 15106
# 1
# --------
# 15222
# 38
# --------
# 15201
# 73
# --------
# 15221
# 11
# --------
# 16001
# 1
# --------
# 15238
# 1
# --------
# 15218
# 5
# --------

# %% [markdown]
# **Conclusion**
#
# From the data we can see that the top three zip codes with the most Smart Trash Containers are:
# 1. 15212 (Brighton Heights) with 166 trash containers
# 2. 15206 (Larimer) with 149 trash containers
# 3. 15219 (Downtown Pittsburgh) with 111 trash containers

# %% [markdown]
# Secondly, we'll read in <font color ='green'>Dataset 2: Greenways</font> and display the first 10 rows, while also printing the columns for **greenway amount**, **name**, and **neighborhood in which it resides**.

# %% [markdown]
# ## DATASET 2: Greenways 🌳

# %% [markdown]
# ![greenways.png](attachment:23a544bc-12ed-4056-a4e5-fb5f257f15af.png)

# %%
greenways = pd.read_csv('https://data.wprdc.org/datastore/dump/28116520-b7d4-4895-9d4f-6b5c843a5650')

# Print the first 10 rows
greenways.head(11)

# Print the column for the amount of greenways and the areas they're located in
greenways.iloc[:, [5, 6, 9]]
# Out:
#    greenway_i                       name                nhood
# 0           1  Spring Hill Spring Garden                  NaN
# 1           4      Beechview Seldom Seen            Beechview
# 2           2                  Hazelwood            Hazelwood
# 3           7                Perry South          Perry South
# 4           6                      Moore            Brookline
# 5           8   Observatory Hill Hollows          Perry North
# 6           9            Allegheny River                  NaN
# 7          10                  Oakcliffe        South Oakland
# 8          11                    Bigelow                  NaN
# 9          12              Nine Mile Run  Squirrel Hill South

# %% [markdown]
# Since that chunk of information looks pretty <font color ='green'> mid</font>, lets spice it up with a bar graph. Then, using a series, we'd insert the data and replace the NaN sections with the name of said neighborhood in which the garden is located.

# %%
# Created a series for the greenways and filled in the nhoods for SHG, AR, and B greenways
greenways = pd.Series([1,4,2,7,6,8,9,10,11,12], index=["Spring Hill", "Beechview", "Hazelwood", "Perry South", "Brookline", "Perry North", "Larimer", "South Oakland", "Hill District", "Squirrel Hill South"])

# Plot the bar graph
greenways.plot(kind="bar")

# %% [markdown]
# **Results:**
# Squirrel Hill ended up having the most Greenways with a total of 12. Following close behind were:
# 1. Hill District w/ 11
# 2. South Oakland w/ 10
# 3. Larimer w/ 9

# %% [markdown]
# ## DATASET 3: Food Gardens 🌾

# %% [markdown]
# ![foodgardens.png](attachment:d0d84145-1ffe-4512-bdd8-fec93738e4ee.png)

# %% [markdown]
# Finally, we'll read in  <font color ='green'>Dataset 3: Food Gardens</font> and create a dictionary for it. Then we'd iterate through the dataframe, get the zip codes, amount of gardens in that zip code, and add to the qauantitiy if it's in the dictionary or set it to a quantity if it's not.

# %%
foodGardens = pd.read_csv('https://data.wprdc.org/dataset/0d8c9708-3f01-48c4-adff-04d29825c9a2/resource/dbdfcb3e-8fa5-4468-9b05-f69562798f7a/download/growpghgardens201712.csv')

# Create a dictionary so for each zip code 
foodGardens_dict = dict()

# iterate through the dataframe
for i in range(len(foodGardens)):
    # get the zip code and quantity of gardens
    item = foodGardens.loc[i, 'zip_code']
    
    if item in foodGardens_dict: # if it's in the dict
        foodGardens_dict[item] += 1 # add the quantity to it
    else:
        foodGardens_dict[item] = 1 # otherwise, set it to the quantity

# %% [markdown]
# Then we'd convert the data into a series

# %%
foodGardens_series = pd.Series(foodGardens_dict, name = "Gardens")

# %% [markdown]
# Finally, we'd sort and list the data in acending order

# %%
foodGardens_series.sort_values()[:]
# Out:
# 15131.0     1
# NaN         1
# 15132.0     1
# 15223.0     1
# 15203.0     1
# 15218.0     1
# 15120.0     1
# 15260.0     1
# 15204.0     1
# 16335.0     1
# 16511.0     1
# 15135.0     1
# 16441.0     1
# NaN         1
# 15106.0     1
# 15237.0     1
# 15025.0     1
# 15102.0     1
# 15342.0     1
# 15108.0     1
# 15205.0     1
# 15202.0     1
# 15235.0     1
# 15214.0     1
# 15217.0     2
# 15212.0     2
# 15238.0     2
# 15220.0     2
# 15224.0     3
# 15210.0     3
# 15207.0     3
# 15208.0     4
# 15213.0     5
# 15201.0     5
# 15221.0     5
# 15219.0     7
# 15206.0    13
# Name: Gardens, dtype: int64

# %%
# Created a series for the Food Gardens and removed Food Gardens not located in Pittsburgh, PA
greenways = pd.Series([1,1,2,4,2,3,3,4,4,6,5,5,7,13], index=["15223 (Sharpsburg)", "15203 (South Side)", "15217 (Squirrel Hill)", "15212 (Northside)", "15220 (Banksville)", "15224 (Garfield)", "15210 (Carrick)", "15207 (Hazelwood)", "15208 (Point Breeze)", "15213 (Oakland)", "15201 (Lawrenceville)", "15221 (Homewood)", "15219 (Schenley Heights)", "15206 (Larimer)"])

# Plot the bar graph
greenways.plot(kind="bar")

# %% [markdown]
# **Results:** Larimer ended up having the most Food Gardens with a total of 13. Following close behind were:
# 1. Schenley Heights w/ 7
# 2. Homewood w/ 5
# 3. Lawrenceville w/ 5

# %% [markdown]
# # IN CONCLUSION:
# ### Results
# The best neighborhood based which one had the highest number in all three categories is  <font color ='green'>**Larimer**</font> with a total of <font color ='green'>149 Smart Trash Containers, 9 Greenways, 13 Food Gardens</font>. Giving it a eco friendly score of 171. The runner ups are:
# 1. Brighton Heights (166 Trash Containers, 0 Greenways, 2 Food Gardens) = 168
# 2. Squirrel Hill (99 Smart Trash Container, 12 Greenways, 2 Food Gardens) = 113
# 3. Oakland (67 Smart Trash Containers, 10 Greenways, and 6 Food Gardens) = 83
# ### Opinions
#  <font color ='green'>Cassandra</font>
# 1. My initial opinion was that the Lower Hill District would be more eco friendly based off of the gardens and greenery that I've personally seen and been to. I was surprised however that Larimer was the most eco friendly because based off of appearances it didn't strike me as being so.
#
# <font color ='green'>Saajan</font>
# 1. My initial opinion was that Oakland or the Squirrel Hill region would be the most eco-friendly due to Schenley Park, however, I did not consider that specific factors we used to decide which neighborhood is the most eco-friendly. I was glad to see my predictions weren't far off as both neighborhoods were in the top 4 most eco-friendly areas.
